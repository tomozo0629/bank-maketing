# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bank_data = pd.read_csv("2_bank_marketing_train.csv")

# %%
bank_data_retired = pd.read_csv("retired_bank_marketing_train.csv")

# %%
yes = bank_data[bank_data["y"] == 1]

# %%
retired = bank_data[bank_data["job"] == "retired"]

# %%
retired["age"].plot.hist(alpha=0.5,color='blue',bins=50)
yes["age"].plot.hist(alpha=0.5,color='red',bins=50)
plt.legend(['retired','yes'])
plt.show()

# %%
bank_data_student = pd.read_csv("student_bank_marketing_train.csv")

# %%
yes = bank_data_student[bank_data_student["y"] == 1]
student = bank_data_student[bank_data_student["job"] == "student"]

# %%
student["age"].plot.hist(alpha=0.5,color='blue',bins=30)
yes["age"].plot.hist(alpha=0.5,color='red',bins=30)
plt.legend(['student','yes'])
plt.show()

# %%
no["age"].plot.hist(alpha=0.5,color='blue',bins=50)
yes["age"].plot.hist(alpha=0.5,color='red',bins=50)
plt.legend(['yes','no'])
plt.show()

# %%
job_pivot = bank_data.pivot_table(index="job",values="y")
job_pivot.plot.bar()
plt.show()

# %%
month_pivot = bank_data.pivot_table(index="month",values="y")
month_pivot.plot.bar()
plt.show()

# %%
poutcome_pivot = bank_data.pivot_table(index="poutcome",values="y")
poutcome_pivot.plot.bar()
plt.show()

# %%
education_pivot = bank_data.pivot_table(index="education",values="y")
education_pivot.plot.bar()
plt.show()

# %%
default_pivot = bank_data.pivot_table(index="default",values="y")
default_pivot.plot.bar()
plt.show()

# %%
contact_pivot = bank_data.pivot_table(index="contact",values="y")
contact_pivot.plot.bar()
plt.show()

# %%
poutcome_pivot = bank_data.pivot_table(index="poutcome",values="y")
poutcome_pivot.plot.bar()
plt.show()
